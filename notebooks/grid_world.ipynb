# %% [markdown]
# Import graphical models classess

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from rlbp.factor import *
from rlbp.graph import *
from rlbp.belief_propagation import *

# %% [markdown]
# Define a grid world as a factor graph
